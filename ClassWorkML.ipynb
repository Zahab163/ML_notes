# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/ML_notes/blob/main/ClassWorkML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Polynomial Regression
import numpy as np
import matplotlib.pyplot as plt # Import matplotlib
from sklearn.linear_model import LinearRegression # Import LinearRegression

np.random.seed(42)
m= 100
X = 6 * np.random.rand(m, 1) - 3
#y = aX**2
y = 0.5 * X**2 + X + 2 + np.random.randn(m,1)

#Apply polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)

# Train a Linear Regression model on the polynomial features
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)

# Generate new data for plotting the regression line
X_new = np.linspace(-3, 3, 100).reshape(-1, 1)
X_new_poly = poly_features.transform(X_new)
y_new = lin_reg.predict(X_new_poly)

#Display polynomial Regression on scatter plot by importing matplotlib

plt.axis([-3, 3, 0, 10]) # Adjusted axis limits for better visualization
plt.scatter(X, y)
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions") # Use X_new for plotting the line
plt.legend(loc="upper left")
plt.show()

# %%
from.sklearn.pipeline import make_pipeline
poly_reg = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
poly_reg.fit(X, y)
y_new = poly_reg.predict(X_new)
train_sizes, train_scores, test_scores = learning_curve(
    poly_reg, X, y, train_sizes=np.linespace(0.01, 1.0, 40), cv=5, scoring='neg_mean_squared_error')
train_scores_mean = -train_scores.mean(axis=1)
valid_scores_mean = -valid_scores.mean(axis=1)
plt.figure(figsize=(10, 6)),
plt.plot(train_sizes, train_errors, "r-+", linewidth=2 label='Training Error')
plt.plot(train_sizes, test_sco, label='Validation Error')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-104403217.py in <cell line: 0>()
# ----> 1 from.sklearn.pipeline import make_pipeline
#       2 poly_reg = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
#       3 poly_reg.fit(X, y)
#       4 y_new = poly_reg.predict(X_new)
#       5 train_sizes, train_scores, test_scores = learning_curve(
#
# ImportError: attempted relative import with no known parent package
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Bais?variance TradeOff
# bais high > var low
# bais low > var high
# Data is assume to be linear but actually it is a Quadratic .
# bias high = Underfit
# l1 and L2
# Regulization
# minimize the weight as much as possible
# Ridge Regression l2
# lasso Regressions l1
# ElasticNet Regression l1 +l2
# all of them work on l1 and l2
# Random
# seed (as provided earlier)
# M.SE
# lamda?palenty
# differences and uses of them
# mx =weight
# RMSE, MSE, MAE,Regression R2.score
# CNN Models
# Accuracy
# research Paper
# lOGISTIC REGRESSION: Work on category
# Raj
